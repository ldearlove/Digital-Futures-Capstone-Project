# %%
import requests
import pandas as pd
import json

# %%
# Set your Steam API key
api_key = "A9283666CBEBA01186FF7EB5D8F80120"

# Set the API endpoint and parameters
url = f"http://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/?key={api_key}&steamid=76561198042246813&format=json"

# Make the API call
response = requests.get(url)

# Parse the response
data = json.loads(response.text)

# Extract the user's game data

games = data["response"]["games"]

# Note: playtime_forever is in minutes
for game in games:
    print(game["appid"], game["playtime_forever"])
# Out:
# 4000 7492
# 4700 273
# 4760 13636
# 19900 588
# 10090 580
# 17410 273
# 22120 354
# 22140 253
# 22180 257
# 22330 549
# 22320 367
# 35700 111
# 6060 181
# 3700 463
# 32370 2314
# 6030 29
# 6020 2453
# 20900 355
# 22370 1665
# 48700 27214
# 33220 1542
# 21130 335
# 57300 1320
# 21970 1172
# 8930 19558
# 7520 64
# 34330 3186
# 10 34
# 20 0
# 30 0
# 40 0
# 50 0
# 60 4
# 70 0
# 80 0
# 100 32
# 130 0
# 220 650
# 240 127
# 280 646
# 300 10
# 320 165
# 340 19
# 360 0
# 380 187
# 400 180
# 420 186
# 500 50
# 550 728
# 620 619
# 72200 208
# 48720 713
# 105600 10608
# 20920 362
# 28050 2567
# 72850 8756
# 55230 118
# 204120 0
# 22380 4580
# 108710 0
# 207610 787
# 6980 125
# 211600 26
# 211740 1
# 20500 126
# 20530 54
# 20550 0
# 55110 111
# 667720 0
# 211420 3652
# 208580 3928
# 212680 15
# 200170 677
# 9050 0
# 9070 0
# 208200 62
# 219640 1129
# 220240 782
# 203140 790
# 205930 0
# 222980 117
# 218230 355
# 1083500 0
# 238960 76
# 223710 24
# 107410 1442
# 220200 497
# 214950 15683
# ...
